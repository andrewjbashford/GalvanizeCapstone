# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from textblob.sentiments import NaiveBayesAnalyzer

import pandas as pd
import sqlite3
from textblob import TextBlob

conn = sqlite3.connect("data/database.sqlite 2")
df = pd.read_sql_query("select * from reviews;", conn)
df_years = pd.read_sql_query("select * from years;", conn)
df_genres = pd.read_sql_query("select * from genres", conn)
df_reviews = pd.read_sql_query("select * from content", conn)

# %%
df.drop_duplicates('pub_date', keep='first', inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3950 entries, 0 to 18392
# Data columns (total 13 columns):
# reviewid          3950 non-null int64
# title             3950 non-null object
# artist            3950 non-null object
# url               3950 non-null object
# score             3950 non-null float64
# best_new_music    3950 non-null int64
# author            3950 non-null object
# author_type       3209 non-null object
# pub_date          3950 non-null object
# pub_weekday       3950 non-null int64
# pub_day           3950 non-null int64
# pub_month         3950 non-null int64
# pub_year          3950 non-null int64
# dtypes: float64(1), int64(6), object(6)
# memory usage: 432.0+ KB

# %%
def plot_violins(df, genre):
    years = list(df.pub_year.unique())
    score_dist = {1999: [],}
    for score,year in zip(df.score.astype(list), df.pub_year.astype(list)):
        if year not in score_dist.keys():
            score_dist[year] = []
        else:
            score_dist[year] = score_dist[year] + [score]

    plt.figure(figsize=(30,14))
    plt.hlines(8.5, 1998, 2018)
    for each in years:
        plt.xticks(years, fontsize=16)
        plt.yticks(range(0,11))
        if each == 2017:
            continue
        plt.violinplot(np.array(score_dist[each]), [each], widths=1,showmedians=True,showextrema=True)
    plt.title('Score Distribution by Year ({})'.format(genre), fontsize=24)
    plt.ylabel('Score', fontsize=16)
    plt.xlabel('Year', fontsize=16)

    plt.savefig('images/{}.png'.format(genre[:3]))

# %%
plot_violins(df, 'all')

# %%
df = df.merge(df_years).reset_index()
df = df.merge(df_genres).reset_index()
df.year.fillna(value=df.pub_year, inplace=True)
df.drop_duplicates('reviewid',inplace=True)
df.drop(['level_0', 'index'], axis=1, inplace=True)
df.year = df.year.astype(int)

# %%
df['num_years_since_release'] = df.pub_year - df.year
df = df[df.num_years_since_release <= 1]

# %%
plot_violins(df, 'all')

# %%
df = df.merge(df_reviews)

# %%
sentiments = []
for each in range(len(df['reviewid'])):
    sentiments.append((df['reviewid'].iloc[each], 
                     TextBlob(df['content'][each]).sentiment[1],
                     TextBlob(df['content'][each]).sentiment[0])) 
#                      TextBlob(df_reviews['content'][each], analyzer=NaiveBayesAnalyzer()).sentiment[0],
#                      TextBlob(df_reviews['content'][each], analyzer=NaiveBayesAnalyzer()).sentiment[1],
#                      TextBlob(df_reviews['content'][each], analyzer=NaiveBayesAnalyzer()).sentiment[2]))

# %%
df_sent = pd.DataFrame(sentiments, columns=['reviewid', 'subjectivity', 'polarity'])

# %%
df_sent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3718 entries, 0 to 3717
# Data columns (total 3 columns):
# reviewid        3718 non-null int64
# subjectivity    3718 non-null float64
# polarity        3718 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 87.2 KB

# %%
df = df.merge(df_sent)

# %%
plt.hist(df['polarity'])
# Out:
# (array([  1.00000000e+00,   5.00000000e+00,   4.40000000e+01,
#           2.23000000e+02,   8.72000000e+02,   1.38800000e+03,
#           9.15000000e+02,   2.48000000e+02,   2.20000000e+01,
#           2.00000000e+00]),
#  array([-0.16815476, -0.11592262, -0.06369048, -0.01145833,  0.04077381,
#          0.09300595,  0.1452381 ,  0.19747024,  0.24970238,  0.30193452,
#          0.35416667]),
#  <a list of 10 Patch objects>)

# %%
def plot_violins(df, genre):
    years = list(df.pub_year.unique())
    score_dist = {1999: [],}
    for score,year in zip(df.score.astype(list), df.pub_year.astype(list)):
        if year not in score_dist.keys():
            score_dist[year] = []
        else:
            score_dist[year] = score_dist[year] + [score]

    plt.figure(figsize=(30,14))
    plt.hlines(8.5, 1998, 2018)
    for each in years:
        plt.xticks(years, fontsize=16)
        plt.yticks(range(0,11))
        if each == 2017:
            continue
        plt.violinplot(np.array(score_dist[each]), [each], widths=1,showmedians=True,showextrema=True)
    plt.title('Score Distribution by Year ({})'.format(genre), fontsize=24)
    plt.ylabel('Score', fontsize=16)
    plt.xlabel('Year', fontsize=16)

# %%
plot_violins(df, 'all')

# %%
df.groupby('pub_year')['subjectivity'].mean()
# Out:
# pub_year
# 1999    0.505105
# 2000    0.498052
# 2001    0.490841
# 2002    0.495215
# 2003    0.496425
# 2004    0.496584
# 2005    0.492034
# 2006    0.491158
# 2007    0.483968
# 2008    0.479469
# 2009    0.482504
# 2010    0.486871
# 2011    0.483036
# 2012    0.485927
# 2013    0.481610
# 2014    0.476273
# 2015    0.479104
# 2016    0.471946
# 2017    0.460377
# Name: subjectivity, dtype: float64

# %%
years = df.groupby('pub_year')['pub_year'].mean().values
plt.plot(df.groupby('pub_year')['pub_year'].mean(), df.groupby('pub_year')['subjectivity'].mean())
plt.xticks(years, rotation=45)
plt.title('Top Review Subjectivity By Year')
plt.show()

# %%
years = df.groupby('pub_year')['pub_year'].mean().values
plt.plot(df.groupby('pub_year')['pub_year'].mean(), df.groupby('pub_year')['polarity'].mean())
plt.xticks(years, rotation=45)
plt.title('Top Review Polarity by Year')
plt.show()

# %%
from scipy.stats import ttest_ind

sub2015 = df[df['year'] == 2015]['subjectivity']
sub2016 = df[df['year'] == 2016]['subjectivity']

t, p = ttest_ind(sub2015, sub2016, equal_var=False)

p
# Out:
# 0.038190429220057741

# %%
pol2015 = df[df['year'] == 2010]['polarity']
pol2016 = df[df['year'] == 2016]['polarity']

t, p = ttest_ind(pol2015, pol2016, equal_var=False)

p
# Out:
# 0.015885552526549666

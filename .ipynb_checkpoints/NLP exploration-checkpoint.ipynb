# %%
import matplotlib.pyplot as plt
# %matplotlib inline

from textblob.sentiments import NaiveBayesAnalyzer

import pandas as pd
import sqlite3
from textblob import TextBlob

conn = sqlite3.connect("data/database.sqlite 2")
df = pd.read_sql_query("select * from reviews;", conn)
df_years = pd.read_sql_query("select * from years;", conn)
df_genres = pd.read_sql_query("select * from genres", conn)
df_reviews = pd.read_sql_query("select * from content", conn)

# %%
TextBlob(df_reviews['content'][1000], analyzer=NaiveBayesAnalyzer()).sentiment
# Out:
# Sentiment(classification='pos', p_pos=1.0, p_neg=3.876155213920638e-20)

# %%
len(sentiments)
# Out:
# 140

# %%
sentiments = []
polarity = []
for each in range(len(df['reviewid'])):
    sentiments.append((df_reviews['reviewid'].iloc[each], TextBlob(df_reviews['content'][each]).sentiment[1],
                     TextBlob(df_reviews['content'][each]).sentiment[0], TextBlob(df_reviews['content'][each], analyzer=NaiveBayesAnalyzer()).sentiment[0],
                     TextBlob(df_reviews['content'][each], analyzer=NaiveBayesAnalyzer()).sentiment[1],
                     TextBlob(df_reviews['content'][each], analyzer=NaiveBayesAnalyzer()).sentiment[2]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-113-00313854140e> in <module>()
#       4     sentiments.append((df_reviews['reviewid'].iloc[each], TextBlob(df_reviews['content'][each]).sentiment[1],
#       5                      TextBlob(df_reviews['content'][each]).sentiment[0], TextBlob(df_reviews['content'][1], analyzer=NaiveBayesAnalyzer()).sentiment[0],
# ----> 6                      TextBlob(df_reviews['content'][1], analyzer=NaiveBayesAnalyzer()).sentiment[1],
#       7                      TextBlob(df_reviews['content'][1], analyzer=NaiveBayesAnalyzer()).sentiment[2]))
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/textblob/decorators.pyc in __get__(self, obj, cls)
#      22         if obj is None:
#      23             return self
# ---> 24         value = obj.__dict__[self.func.__name__] = self.func(obj)
#      25         return value
#      26
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/textblob/blob.pyc in sentiment(self)
#     406         :rtype: namedtuple of the form ``Sentiment(polarity, subjectivity)``
#     407         """
# --> 408         return self.analyzer.analyze(self.raw)
#     409
#     410     @cached_property
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/textblob/en/sentiments.pyc in analyze(self, text)
#      74         """
#      75         # Lazily train the classifier
# ---> 76         super(NaiveBayesAnalyzer, self).analyze(text)
#      77         tokens = word_tokenize(text, include_punc=False)
#      78         filtered = (t.lower() for t in tokens if len(t) >= 3)
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/textblob/base.pyc in analyze(self, text)
#      91         # Lazily train the classifier
#      92         if not self._trained:
# ---> 93             self.train()
#      94         # Analyze text
#      95         return None
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/textblob/decorators.pyc in decorated(*args, **kwargs)
#      33     def decorated(*args, **kwargs):
#      34         try:
# ---> 35             return func(*args, **kwargs)
#      36         except LookupError as err:
#      37             print(err)
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/textblob/en/sentiments.pyc in train(self)
#      63         pos_ids = nltk.corpus.movie_reviews.fileids('pos')
#      64         neg_feats = [(self.feature_extractor(
# ---> 65             nltk.corpus.movie_reviews.words(fileids=[f])), 'neg') for f in neg_ids]
#      66         pos_feats = [(self.feature_extractor(
#      67             nltk.corpus.movie_reviews.words(fileids=[f])), 'pos') for f in pos_ids]
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/textblob/en/sentiments.pyc in _default_feature_extractor(words)
#      35 def _default_feature_extractor(words):
#      36     """Default feature extractor for the NaiveBayesAnalyzer."""
# ---> 37     return dict(((word, True) for word in words))
#      38
#      39
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/textblob/en/sentiments.pyc in <genexpr>(***failed resolving arguments***)
#      35 def _default_feature_extractor(words):
#      36     """Default feature extractor for the NaiveBayesAnalyzer."""
# ---> 37     return dict(((word, True) for word in words))
#      38
#      39
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/nltk/corpus/reader/util.pyc in iterate_from(self, start_tok)
#     294             self._current_toknum = toknum
#     295             self._current_blocknum = block_index
# --> 296             tokens = self.read_block(self._stream)
#     297             assert isinstance(tokens, (tuple, list, AbstractLazySequence)), (
#     298                 'block reader %s() should return list or tuple.' %
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/nltk/corpus/reader/plaintext.pyc in _read_word_block(self, stream)
#     120         words = []
#     121         for i in range(20): # Read 20 lines at a time.
# --> 122             words.extend(self._word_tokenizer.tokenize(stream.readline()))
#     123         return words
#     124
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/nltk/tokenize/regexp.pyc in tokenize(self, text)
#     127         # If our regexp matches tokens, use re.findall:
#     128         else:
# --> 129             return self._regexp.findall(text)
#     130
#     131     def span_tokenize(self, text):
#
# KeyboardInterrupt:

# %%
df_sent = pd.DataFrame(sentiments, columns=['reviewid', 'subjectivity', 'polarity', 'classification', 'p_pos', 'p_neg'])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-109-eca2c0231081> in <module>()
# ----> 1 df_sent = pd.DataFrame(sentiments, columns=['reviewid', 'subjectivity', 'polarity', 'classification', 'p_pos', 'p_neg'])
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/pandas/core/frame.pyc in __init__(self, data, index, columns, dtype, copy)
#     312                     if is_named_tuple(data[0]) and columns is None:
#     313                         columns = data[0]._fields
# --> 314                     arrays, columns = _to_arrays(data, columns, dtype=dtype)
#     315                     columns = _ensure_index(columns)
#     316
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/pandas/core/frame.pyc in _to_arrays(data, columns, coerce_float, dtype)
#    5615     if isinstance(data[0], (list, tuple)):
#    5616         return _list_to_arrays(data, columns, coerce_float=coerce_float,
# -> 5617                                dtype=dtype)
#    5618     elif isinstance(data[0], collections.Mapping):
#    5619         return _list_of_dict_to_arrays(data, columns,
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/pandas/core/frame.pyc in _list_to_arrays(data, columns, coerce_float, dtype)
#    5694         content = list(lib.to_object_array(data).T)
#    5695     return _convert_object_array(content, columns, dtype=dtype,
# -> 5696                                  coerce_float=coerce_float)
#    5697
#    5698
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/pandas/core/frame.pyc in _convert_object_array(content, columns, coerce_float, dtype)
#    5753             # caller's responsibility to check for this...
#    5754             raise AssertionError('%d columns passed, passed data had %s '
# -> 5755                                  'columns' % (len(columns), len(content)))
#    5756
#    5757     # provide soft conversion of object dtypes
#
# AssertionError: 6 columns passed, passed data had 3 columns

# %%
df = df.merge(df_sent)

# %%
df.sort_values('polarity', ascending=False)
# Out:
#        reviewid                                              title  \
# 18356      2265                                            peloton
# 7543      14503                            tiger flower circle sun
# 15610      1076                                   the omaha record
# 14044      2067                            a house full of friends
# 17696      7565                          a celebratory arm gesture
# 10242     11452                           the best of joy division
# 14665      4458                                muswell hillbillies
# 11019     10582                                  city morning song
# 14117      3334                                    has a good home
# 18287      3224                                    love is real ep
# 2650      19901                                    tha tour part 1
# 1268      21377                                           from joy
# 7699      14349                                    the five ghosts
# 319       22432                             if you see me, say yes
# 13466      6420                                       bright ideas
# 14227      6903  the surviving elements: from the soul survivor...
# 8030      14030                                       massa hypnos
# 13613      1572                                layourbattleaxedown
# 14362      6782                 not so much to be loved as to love
# 17379      5395                                   change is coming
# 8348      13731                                          maybes ep
# 6503      15584                                             sagara
# 8227      13820                    francophonic, vol. 2: 1980-1989
# 1168      21502                                    nine track mind
# 1645      20945              tales from the land of milk and honey
# 374       22305                                              orphe
# 12856      1197                                   o true believers
# 10859     10761                               oracular spectacular
# 4285      17813                                   sing to the moon
# 801       21869                      happy songs for happy zombies
# ...         ...                                                ...
# 10290     11342                        the blood pressure sessions
# 14213      2593                                       girls of war
# 12928      7845                                 young for eternity
# 15487       749                             wolf eyes & black dice
# 12075      9490                          voices of animals and men
# 15510      6204                                       fatherfucker
# 17306      8342                                     perdition city
# 18143       209                                    tragic epilogue
# 16737      6999                                     airdrawndagger
# 14413      5830        terra incognita: ambient works 1975-present
# 16168     11689                       butthole surfers/live pcppep
# 15574      3626                                         jessica ep
# 13160      2588                             romance bloody romance
# 12197      9393  on cutting ti-gers in half and understanding n...
# 15473      8704                                      the dirt tier
# 12407      9188                                a call and response
# 18142      8502                                                vue
# 14478      2582                                               late
# 6483      15600                                           ceremony
# 13999      2602                                  the dissociatives
# 17849       325                                    apple street ep
# 12703      3365                     nothing positive only negative
# 15474      3539                      the bootleg of the bootleg ep
# 13306       488                                           suckfish
# 2149      20383                                   nasty witch rock
# 17084      8936  put your phazers on stun throw your health foo...
# 14059      4980                                  illegal tender ep
# 3891      18478                                       weird sister
# 18379      1514                                             clinic
# 12578      9045                                           passover
#
#                                      artist  \
# 18356                          the delgados
# 7543                    christopher willits
# 15610                  bottom of the hudson
# 14044                       various artists
# 17696                          summer hymns
# 10242                          joy division
# 14665                             the kinks
# 11019                         sarah shannon
# 14117                         final fantasy
# 18287                           edith frost
# 2650   birdman, young thug, rich homie quan
# 1268                              kyle hall
# 7699                                  stars
# 319                          flock of dimes
# 13466                           portastatic
# 14227                             pete rock
# 8030                          awesome color
# 13613                         the concretes
# 14362                      jonathan richman
# 17379                            money mark
# 8348                           mount kimbie
# 1168             2        3          2      2016      0.528184  0.294718
# 1645             3       20          8      2015      0.483354  0.293245
# 374              1       13          9      2016      0.489744  0.292920
# 12856            0        6          3      2006      0.595155  0.291860
# 10859            0       22         10      2007      0.566310  0.291756
# 4285             0       20          5      2013      0.477870  0.290278
# 801              1       17          5      2016      0.582910  0.289841
# ...            ...      ...        ...       ...           ...       ...
# 10290            3       17          4      2008      0.445448 -0.066903
# 14213            1       25          1      2005      0.420965 -0.069416
# 12928            1       14          2      2006      0.451854 -0.070519
# 15487            1        4         11      2003      0.456913 -0.071319
# 12075            0       23         10      2006      0.569402 -0.072700
# 15510            2       29         10      2003      0.601434 -0.074431
# 17306            3       24          1      2002      0.560051 -0.074876
# 18143            1       22          2      2000      0.568183 -0.075309
# 16737            6       25          8      2002      0.395620 -0.076872
# 14413            3        4         11      2004      0.418678 -0.078631
# 16168            3        3          4      2003      0.525046 -0.079813
# 15574            6       12         10      2003      0.432074 -0.079874
# 13160            1       22         11      2005      0.532409 -0.080793
# 12197            3       21          9      2006      0.480324 -0.083102
# 15473            6        9         11      2003      0.541435 -0.085518
# 12407            4       14          7      2006      0.545020 -0.088564
# 18142            1       22          2      2000      0.527281 -0.089222
# 14478            6       17         10      2004      0.506212 -0.089562
# 6483             1        5          7      2011      0.444737 -0.098794
# 13999            3       24          3      2005      0.537460 -0.102528
# 17849            3       30         11      2000      0.585855 -0.104057
# 12703            1       18          4      2006      0.496670 -0.108698
# 15474            6        9         11      2003      0.476188 -0.110580
# 13306            2       12         10      2005      0.521077 -0.121158
# 2149             3       26          3      2015      0.522191 -0.136846
# 17084            2       17          4      2002      0.573299 -0.137015
# 14059            2        9          3      2005      0.521852 -0.142460
# 3891             4       13          9      2013      0.659396 -0.164796
# 18379            0        1          3      1999      0.503869 -0.168155
# 12578            2       24          5      2006      0.531635 -0.173614
#
# [18401 rows x 15 columns]

# %%
df_subj_byyear = df[df['score'] > 8].groupby('pub_year').mean().reset_index()
df_subj_byyear
# Out:
#     pub_year      reviewid     score  best_new_music  pub_weekday    pub_day  \
# 0       1999   4693.807018  8.721053        0.000000     1.368421  16.543860
# 1       2000   4657.718310  8.649296        0.000000     1.647887  18.535211
# 2       2001   5170.852459  8.677869        0.000000     2.098361  17.754098
# 3       2002   4379.396739  8.605978        0.000000     2.211957  14.788043
# 4       2003   4727.454167  8.533333        0.187500     2.262500  15.216667
# 5       2004   4938.600858  8.568670        0.184549     2.150215  15.171674
# 6       2005   4723.014778  8.592118        0.192118     2.256158  15.246305
# 7       2006   7858.371728  8.516230        0.162304     2.057592  15.366492
# 8       2007  10383.145833  8.547917        0.223958     2.114583  15.697917
# 9       2008  11708.615385  8.549451        0.197802     1.961538  15.873626
# 10      2009  13206.421687  8.634337        0.506024     2.090361  14.325301
# 11      2010  14336.088398  8.471271        0.458564     2.033149  15.303867
# 12      2011  15551.522293  8.497452        0.515924     2.101911  15.433121
# 13      2012  16718.943038  8.512025        0.563291     2.031646  16.746835
# 14      2013  18150.562092  8.482353        0.607843     1.915033  15.078431
# 15      2014  19467.895105  8.548252        0.629371     1.860140  15.664336
# 16      2015  20699.741935  8.499194        0.612903     1.967742  15.354839
# 17      2016  22013.260274  8.613242        0.406393     2.780822  15.799087
# 18      2017  22708.500000  8.750000        0.500000     3.750000   5.750000
#
#     pub_month  subjectivity  polarity
# 0    6.070175      0.496134  0.138941
# 1    6.267606      0.499345  0.104843
# 2    8.057377      0.493938  0.126801
# 3    5.880435      0.495729  0.121573
# 4    6.300000      0.498318  0.114732
# 5    6.283262      0.490729  0.122056
# 6    6.157635      0.488605  0.121588
# 7    6.544503      0.490974  0.135348
# 8    5.916667      0.486204  0.125954
# 9    6.208791      0.485335  0.137519
# 10   6.873494      0.480442  0.138515
# 11   6.082873      0.490695  0.143834
# 12   6.375796      0.482016  0.133574
# 13   5.955696      0.487685  0.126415
# 14   6.352941      0.483795  0.123328
# 15   6.650350      0.476206  0.110814
# 16   6.838710      0.471974  0.120422
# 17   6.461187      0.469196  0.118535
# 18   1.000000      0.470030  0.138744

# %%
years = df_subj_byyear['pub_year'].values

# %%
plt.plot(df_subj_byyear['pub_year'], df_subj_byyear['subjectivity'])
plt.xticks(years, rotation=45)
plt.show()

# %%
from scipy.stats import ttest_ind

sub2015 = df[df['pub_year'] == 2015]['subjectivity']
sub2016 = df[df['pub_year'] == 2016]['subjectivity']

t, p = ttest_ind(sub2015, sub2016, equal_var=False)

p
# Out:
# 0.4840278821782481

# %%
plt.plot(df_subj_byyear['pub_year'], df_subj_byyear['polarity'])
plt.xticks(years, rotation=45)
plt.show()

# %%
testimonial = TextBlob(df_reviews['content'][1000])
sent = testimonial.sentiment

# %%
TextBlob(df_reviews['content'][1000]).sentiment
# Out:
# Sentiment(polarity=0.14763095238095236, subjectivity=0.5278095238095237)

# %%
sentiments[1]
# Out:
# (22721,
#  0.40645743145743146,
#  0.04163961038961039,
#  'pos',
#  0.9999999999861309,
#  1.3892711896181222e-11)

# %%
def plot_violins(df, genre=all):
    years = list(df.pub_year.unique())
    score_dist = {1999: [],}
    for score,year in zip(df.subjectivity.astype(list), df.pub_year.astype(list)):
        if year not in score_dist.keys():
            score_dist[year] = []
        else:
            score_dist[year] = score_dist[year] + [score]

    plt.figure(figsize=(30,14))
    for each in years:
        plt.xticks(years, fontsize=16)
#         plt.yticks(range(0,1))
        if each == 2017:
            continue
        plt.violinplot(np.array(score_dist[each]), [each], widths=1,showmedians=True,showextrema=True)
    plt.title('Subjectivity Distribution by Year ({})'.format(genre), fontsize=24)
    plt.ylabel('Score', fontsize=16)
    plt.xlabel('Year', fontsize=16)

# %%
import numpy as np

# %%
plot_violins(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-117-3cba44f5baa6> in <module>()
# ----> 1 plot_violins(df)
#
# <ipython-input-115-ee3f5f56ba46> in plot_violins(df, genre)
#       2     years = list(df.pub_year.unique())
#       3     score_dist = {1999: [],}
# ----> 4     for score,year in zip(df.subjectivity.astype(list), df.pub_year.astype(list)):
#       5         if year not in score_dist.keys():
#       6             score_dist[year] = []
#
# /Users/andrewbashford/anaconda3/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3079             if name in self._info_axis:
#    3080                 return self[name]
# -> 3081             return object.__getattribute__(self, name)
#    3082
#    3083     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'subjectivity'
